# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv
load_dotenv()
import os

if os.getenv("ANTHROPIC_API_KEY") is None:
    raise ValueError("No API key")
else:
    print("Variable is set")
# Out:
# Variable is set

# %%
llm = ChatAnthropic(model = "claude-haiku-4-5-20251001")

response = llm.invoke("""Give me the code to create a pandas dataframe with 3 columns and 5 rows
                      Please also generate a python file to store the code.""")
response.content
# Out:
# AIMessage(content="# Create a simple pandas DataFrame with 3 columns and 5 rows\n\n```python\nimport pandas as pd\n\ndf = pd.DataFrame({\n    'Column1': [1, 2, 3, 4, 5],\n    'Column2': ['A', 'B', 'C', 'D', 'E'],\n    'Column3': [10.5, 20.3, 15.7, 25.1, 30.9]\n})\n\nprint(df)\n```\n\n**Output:**\n```\n   Column1 Column2  Column3\n0        1       A     10.5\n1        2       B     20.3\n2        3       C     15.7\n3        4       D     25.1\n4        5       E     30.9\n```\n\n**Alternative methods:**\n\n```python\n# Using lists as rows\ndf = pd.DataFrame([\n    [1, 'A', 10.5],\n    [2, 'B', 20.3],\n    [3, 'C', 15.7],\n    [4, 'D', 25.1],\n    [5, 'E', 30.9]\n], columns=['Column1', 'Column2', 'Column3'])\n\n# Using random data\nimport numpy as np\ndf = pd.DataFrame(np.random.rand(5, 3), columns=['A', 'B', 'C'])\n```", additional_kwargs={}, response_metadata={'id': 'msg_013L8prTKhYNo4StZbLcMtgz', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 27, 'output_tokens': 338, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--019cf1ee-8a99-71c3-b1fc-db9e100b4b4b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 338, 'total_tokens': 365, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})
